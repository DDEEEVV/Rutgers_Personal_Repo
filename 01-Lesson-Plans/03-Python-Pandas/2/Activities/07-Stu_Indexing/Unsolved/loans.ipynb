# %% [markdown]
# ### Student Activity: Indexing
#
# This program reads daily stock data from a CSV, trims extraneous columns, sets the date as the index, and calculates and plots returns for a specified date range.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set the path

csvpath = Path("/Users/ddevii/Rutgers/Rutgers_Personal_Repo/01-Lesson-Plans/03-Python-Pandas/2/Activities/07-Stu_Indexing/Resources/loans.csv")

# Read in the CSV as a DataFrame

loans_csv = pd.read_csv(csvpath)

# %% [markdown]
# ### Show the First 10 Records

# %%
# Retrive rows with index 0 up to 10 (not including)
loans_csv.iloc[0:10]
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
# 5      30000        30000          30000.0  60 months    0.1894       777.23
# 6      23000        23000          23000.0  60 months    0.2089       620.81
# 7      32075        32075          32075.0  60 months    0.1180       710.26
# 8       8000         8000           8000.0  36 months    0.2340       311.35
# 9      10000        10000          10000.0  60 months    0.1992       264.50
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             Unknown   < 1 year       MORTGAGE    280000.0
# 1     E        E1            Security    3 years           RENT     90000.0
# 2     D        D1      Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             Unknown        NaN       MORTGAGE     35704.0
# 4     C        C1                Chef  10+ years           RENT     55000.0
# 5     D        D2         Postmaster   10+ years       MORTGAGE     90000.0
# 6     D        D4            Operator    5 years           RENT     68107.0
# 7     B        B4  Nursing Supervisor  10+ years       MORTGAGE    150000.0
# 8     E        E1             Manager  10+ years            OWN     43000.0
# 9     D        D3    Material Handler  10+ years       MORTGAGE     80000.0
#
#   verification_status issue_d loan_status pymnt_plan             purpose
# 0        Not Verified  Dec-18     Current          n  debt_consolidation
# 1     Source Verified  Dec-18     Current          n  debt_consolidation
# 2     Source Verified  Dec-18     Current          n  debt_consolidation
# 3        Not Verified  Dec-18     Current          n    home_improvement
# 4        Not Verified  Dec-18     Current          n  debt_consolidation
# 5     Source Verified  Dec-18     Current          n  debt_consolidation
# 6     Source Verified  Dec-18     Current          n  debt_consolidation
# 7        Not Verified  Dec-18     Current          n         credit_card
# 8     Source Verified  Dec-18     Current          n  debt_consolidation
# 9        Not Verified  Dec-18     Current          n  debt_consolidation

# %% [markdown]
# ### View Summary Statistics

# %%
# Describe summary statistics for csv data
loans_csv.describe(include="all")
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv       term  \
# count   128412.000000  128412.000000    128412.000000     128412
# unique            NaN            NaN              NaN          2
# top               NaN            NaN              NaN  36 months
# freq              NaN            NaN              NaN      88179
# mean     15971.321021   15971.321021     15968.498166        NaN
# std      10150.384233   10150.384233     10152.168970        NaN
# min       1000.000000    1000.000000       725.000000        NaN
# 25%       8000.000000    8000.000000      8000.000000        NaN
# 50%      14000.000000   14000.000000     14000.000000        NaN
# 75%      21600.000000   21600.000000     21600.000000        NaN
# max      40000.000000   40000.000000     40000.000000        NaN
#
#              int_rate    installment   grade sub_grade emp_title emp_length  \
# count   128412.000000  128412.000000  128412    128412    107465     116708
# unique            NaN            NaN       7        35     43892         11
# top               NaN            NaN       A        A4   Teacher  10+ years
# freq              NaN            NaN   38011      9770      2090      38826
# mean         0.129302     463.259353     NaN       NaN       NaN        NaN
# std          0.050904     285.718256     NaN       NaN       NaN        NaN
# min          0.060000      30.480000     NaN       NaN       NaN        NaN
# 25%          0.084600     253.630000     NaN       NaN       NaN        NaN
# 50%          0.118000     382.905000     NaN       NaN       NaN        NaN
# 75%          0.161400     622.680000     NaN       NaN       NaN        NaN
# max          0.309900    1618.240000     NaN       NaN       NaN        NaN
#
#        home_ownership    annual_inc verification_status issue_d loan_status  \
# count          128412  1.284120e+05              128412  128412      128412
# unique              4           NaN                   3       3           7
# top          MORTGAGE           NaN        Not Verified  Oct-18     Current
# freq            63490           NaN               58350   46305      119540
# mean              NaN  8.279733e+04                 NaN     NaN         NaN
# std               NaN  1.082985e+05                 NaN     NaN         NaN
# min               NaN  0.000000e+00                 NaN     NaN         NaN
# 25%               NaN  4.705800e+04                 NaN     NaN         NaN
# 50%               NaN  6.800000e+04                 NaN     NaN         NaN
# 75%               NaN  9.900000e+04                 NaN     NaN         NaN
# max               NaN  9.757200e+06                 NaN     NaN         NaN
#
#        pymnt_plan             purpose
# count      128412              128412
# unique          1                  12
# top             n  debt_consolidation
# freq       128412               70603
# mean          NaN                 NaN
# std           NaN                 NaN
# min           NaN                 NaN
# 25%           NaN                 NaN
# 50%           NaN                 NaN
# 75%           NaN                 NaN
# max           NaN                 NaN

# %% [markdown]
# ### Filter Columns and Create Subset DataFrame

# %%
# Filter the DataFrame down to the following, keep all rows

#loan_amnt
#term
#int_rate
#emp_title
#annual_inc
#purpose

filtered_df=loans_csv.loc[:, ["loan_amnt", "term", "int_rate", "emp_title", "annual_inc", "purpose"]]
filtered_df.head(100)
# Out:
#     loan_amnt       term  int_rate        emp_title  annual_inc  \
# 0       10000  36 months    0.1033              NaN    280000.0
# 1        4000  36 months    0.2340         Security     90000.0
# 2        5000  36 months    0.1797   Administrative     59280.0
# 3        9600  36 months    0.1298              NaN     35704.0
# 4        2500  36 months    0.1356             Chef     55000.0
# ..        ...        ...       ...              ...         ...
# 95      10450  36 months    0.1894  Project Manager     70000.0
# 96      10000  36 months    0.1180    Service tech.    100000.0
# 97      10000  36 months    0.1894    Especialist 1     37115.0
# 98       5000  36 months    0.1131         Shipping     40000.0
# 99      17100  36 months    0.1894    Receptionist      38000.0
#
#                purpose
# 0   debt_consolidation
# 1   debt_consolidation
# 2   debt_consolidation
# 3     home_improvement
# 4   debt_consolidation
# ..                 ...
# 95  debt_consolidation
# 96         credit_card
# 97               other
# 98  debt_consolidation
# 99  debt_consolidation
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Filter Rows by 36 Month Terms

# %%
# Conditional indexing to filter DataFrame where 'term' is equal to '36 months'
term_df = filtered_df.loc[filtered_df["term"] == "36 months"].copy()
term_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %% [markdown]
# ### Modify Row Values

# %%
# Change row values within the 'term' column from '36 months' to '3 Years'
term_df.loc[filtered_df["term"] == "36 months", "term"] = "3 years"
term_df.head()
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 years    0.1033             NaN    280000.0
# 1       4000  3 years    0.2340        Security     90000.0
# 2       5000  3 years    0.1797  Administrative     59280.0
# 3       9600  3 years    0.1298             NaN     35704.0
# 4       2500  3 years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
# Change row values within the 'emp_title' column from NaN to 'Unknown'
term_df.loc[filtered_df["emp_title"].isnull(), "emp_title"] = "Unknown"
term_df.head(1000)
# Out:
#       loan_amnt     term  int_rate                emp_title  annual_inc  \
# 0         10000  3 years    0.1033                  Unknown    280000.0
# 1          4000  3 years    0.2340                 Security     90000.0
# 2          5000  3 years    0.1797           Administrative     59280.0
# 3          9600  3 years    0.1298                  Unknown     35704.0
# 4          2500  3 years    0.1356                     Chef     55000.0
# ...         ...      ...       ...                      ...         ...
# 1440      13000  3 years    0.0881        WAREHOUSE MANAGER     68000.0
# 1441      17000  3 years    0.1691    Educational Assistant     58000.0
# 1442      27000  3 years    0.0881              COURT CLERK     98000.0
# 1446      35000  3 years    0.0819  Senior Property Manager    126000.0
# 1447      10000  3 years    0.1180                  Unknown     98000.0
#
#                  purpose
# 0     debt_consolidation
# 1     debt_consolidation
# 2     debt_consolidation
# 3       home_improvement
# 4     debt_consolidation
# ...                  ...
# 1440  debt_consolidation
# 1441  debt_consolidation
# 1442  debt_consolidation
# 1446  debt_consolidation
# 1447      small_business
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### View Summary Statistics for 3 Year Term Loans

# %%
# Describe summary statistics for three-year loans
term_df.describe(include="all")
term_df.head(1000)
# Out:
#       loan_amnt     term  int_rate                emp_title  annual_inc  \
# 0         10000  3 years    0.1033                  Unknown    280000.0
# 1          4000  3 years    0.2340                 Security     90000.0
# 2          5000  3 years    0.1797           Administrative     59280.0
# 3          9600  3 years    0.1298                  Unknown     35704.0
# 4          2500  3 years    0.1356                     Chef     55000.0
# ...         ...      ...       ...                      ...         ...
# 1440      13000  3 years    0.0881        WAREHOUSE MANAGER     68000.0
# 1441      17000  3 years    0.1691    Educational Assistant     58000.0
# 1442      27000  3 years    0.0881              COURT CLERK     98000.0
# 1446      35000  3 years    0.0819  Senior Property Manager    126000.0
# 1447      10000  3 years    0.1180                  Unknown     98000.0
#
#                  purpose
# 0     debt_consolidation
# 1     debt_consolidation
# 2     debt_consolidation
# 3       home_improvement
# 4     debt_consolidation
# ...                  ...
# 1440  debt_consolidation
# 1441  debt_consolidation
# 1442  debt_consolidation
# 1446  debt_consolidation
# 1447      small_business
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Show Unique Values for Employee Titles with 3 Year Loans

# %%
# Calculate unique values and counts for employee titles of 3 year customer loans
loans_csv["purpose"].value_counts()
# Out:
# debt_consolidation    70603
# credit_card           34961
# home_improvement       7512
# other                  7094
# major_purchase         2303
# medical                1499
# small_business         1051
# car                    1037
# house                   823
# vacation                802
# moving                  656
# renewable_energy         71
# Name: purpose, dtype: int64

# %% [markdown]
# ### Show Unique Values for Purpose of 3 Year Loans

# %%
# Calculate unique values and counts for loan purposes of 3 year customer loans
term_df["purpose"].value_counts()
# Out:
# debt_consolidation    45456
# credit_card           24780
# other                  5836
# home_improvement       5446
# major_purchase         1795
# medical                1245
# car                     838
# small_business          828
# vacation                749
# house                   596
# moving                  547
# renewable_energy         63
# Name: purpose, dtype: int64

# %% [markdown]
# ### Show Summary Statistics for 3 Year Loans of Customers with Annual Income Greater Than $80,000

# %%
# Display summary statistics where annual income is greater than $80,000 to find count and mean
greater80k_df = term_df.loc[filtered_df["annual_inc"] > 80000, "annual_inc"].copy()
greater80k_df.head(29748)
# Out:
# 0         280000.0
# 1          90000.0
# 14         90000.0
# 20        105000.0
# 21        150000.0
#             ...
# 128384    120000.0
# 128386     90000.0
# 128388     97000.0
# 128390     85000.0
# 128393     82000.0
# Name: annual_inc, Length: 29748, dtype: float64

# %%
#find count for annual income more than 80k
greater80k_df.count()
# Out:
# 29748

# %%
#find mean for annual income more than 80k
round(greater80k_df.mean(), 2)
# Out:
# 138963.37

# %% [markdown]
# ### Show Summary Statistics for 3 Year Loans of Customers with Annual Income Less Than $80,000

# %%
# Display summary statistics where annual income is less than $80,000 to find count and mean
less80k_df = term_df.loc[filtered_df["annual_inc"] < 80000, "annual_inc"].copy()
less80k_df.head(56016)
# Out:
# 2         59280.0
# 3         35704.0
# 4         55000.0
# 8         43000.0
# 15        65000.0
#            ...
# 128406    15600.0
# 128407    75000.0
# 128408    38000.0
# 128409    35360.0
# 128410    44400.0
# Name: annual_inc, Length: 56015, dtype: float64

# %%
#find count for annual income with less than 80K
less80k_df.count()
# Out:
# 56015

# %%
#find mean for annual income more than 80k
round(less80k_df.mean(), 2) # which can also be found: round(less80k_df.sum() / less80k_df.count(), 2)
# Out:
# 49372.81

# %% [markdown]
# ### What insights can we answer regarding 3 year loans?
#
# 1. What kind of customers (employee title) seem to ask for three-year loans most frequently?
# 2. What are three-year loans generally used for?
# 3. What is the distribution of three-year loan customers with annual incomes greater than 80,000 compared to those with annual incomes less than 80,000?
# 4. What is the difference between interest rates for customers with annual incomes greater than 80,000 compared to those with annual incomes less than 80,000?
