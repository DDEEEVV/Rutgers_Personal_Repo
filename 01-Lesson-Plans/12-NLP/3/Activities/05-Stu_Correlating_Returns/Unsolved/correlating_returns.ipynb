# %% [markdown]
# # Correlating Returns

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from newsapi.newsapi_client import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer

file_name = "news_df.pkl"

import os.path

# %% [markdown]
# ## Load API Keys from Environment Variables

# %%
# Load .env enviroment variables
load_dotenv()

# Set News API Key
newsapi = NewsApiClient(api_key=os.environ["news_api"])

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %% [markdown]
# ## Get AAPL Returns for Past Month

# %%
# Set the ticker
ticker = "AAPL"

# Set timeframe to '1D'
timeframe = "1D"

# Set current date and the date from one month ago using the ISO format
current_date = pd.Timestamp(datetime.now()- timedelta(1), tz="America/New_York").isoformat()
past_date = pd.Timestamp(datetime.now()- timedelta(31), tz="America/New_York").isoformat()

# Get 4 weeks worth of historical data for AAPL
df = api.get_bars(
    ticker,
    timeframe,
    limit=None,
    start=past_date,
    end=current_date,
).df

# Display data
df.head()
# Out:
#                              open     high     low   close     volume  \
# timestamp
# 2022-05-09 04:00:00+00:00  154.83  155.830  151.49  152.06  131274823
# 2022-05-10 04:00:00+00:00  155.57  156.740  152.93  154.51  114742115
# 2022-05-11 04:00:00+00:00  153.45  155.450  145.81  146.50  142166096
# 2022-05-12 04:00:00+00:00  142.80  146.190  138.80  142.56  181631246
# 2022-05-13 04:00:00+00:00  144.65  148.105  143.11  147.11  113656931
#
#                            trade_count        vwap
# timestamp
# 2022-05-09 04:00:00+00:00      1093220  153.100423
# 2022-05-10 04:00:00+00:00       981091  154.837162
# 2022-05-11 04:00:00+00:00      1297098  149.443367
# 2022-05-12 04:00:00+00:00      1663909  142.068993
# 2022-05-13 04:00:00+00:00       917034  146.325214

# %%
df.index = df.index.date
df = df[["close"]]
df.head()
# Out:
#              close
# 2022-05-09  152.06
# 2022-05-10  154.51
# 2022-05-11  146.50
# 2022-05-12  142.56
# 2022-05-13  147.11

# %%
# Use the `pct_change` function to calculate daily returns of AAPL
aapl_returns = df.pct_change().dropna()

# Display sample data
aapl_returns.head()
# Out:
#                close
# 2022-05-10  0.016112
# 2022-05-11 -0.051841
# 2022-05-12 -0.026894
# 2022-05-13  0.031916
# 2022-05-16 -0.010672

# %%
# Use newsapi client to get most relevant 20 headlines per day in the past month
def get_headlines(keyword):
    """
    Returns
    --------

    two variables, eg.
    
    [
        [
            "Elon buying twitter!!!!",
            "Elon NOT buying twitter!!!!"
        ],
        [
            "No news today..."
        ]
    ]

    ['01/01/2020', '01/02/2020']

    """
    all_headlines = []
    all_dates = []    
    date = datetime.strptime(current_date[:10], "%Y-%m-%d") # global var (current_date)
    end_date = datetime.strptime(past_date[:10], "%Y-%m-%d") # past date... 
    print(f"Fetching news about '{keyword}'")
    print("*" * 30)
    while date > end_date: # loop through each day
        print(f"retrieving news from: {date}")
        articles = newsapi.get_everything( # global newsapi....
            q=keyword,
            from_param=str(date)[:10],
            to=str(date)[:10],
            language="en",
            sort_by="relevancy",
            page=1,
        )
        headlines = [] # headlines for this date
        for i in range(0, len(articles["articles"])): # for each article on that day...
            headlines.append(articles["articles"][i]["title"])
        all_headlines.append(headlines) # add this days news to all the news
        all_dates.append(date) # 
        date = date - timedelta(days=1) # increment out day....
    return all_headlines, all_dates

# %% [markdown]
# Note: Be aware that running the 3 requests below will only work once within a 24 hour period due to the request limits imposed by the API provider.

# %%
# Get first topic
if not os.path.isfile(file_name): 
    aapl_headlines, dates = get_headlines("apple")
    trade_headlines, _ = get_headlines("trade")
    economy_headlines, _ = get_headlines("economy")

    analyzer = SentimentIntensityAnalyzer()

    new_df = pd.DataFrame(
    
            {
                "aaple_news":aapl_headlines,
                "trade_news":trade_headlines,
                "economy_news":economy_headlines,
                "date":dates
            }

    )

    new_df.to_pickle(file_name)

else:
    new_df = pd.read_pickle(file_name)

new_df.head()
# Out:
# Fetching news about 'apple'
# ******************************
# retrieving news from: 2022-06-05 00:00:00
# retrieving news from: 2022-06-04 00:00:00
# retrieving news from: 2022-06-03 00:00:00
# retrieving news from: 2022-06-02 00:00:00
# retrieving news from: 2022-06-01 00:00:00
# retrieving news from: 2022-05-31 00:00:00
# retrieving news from: 2022-05-30 00:00:00
# retrieving news from: 2022-05-29 00:00:00
# retrieving news from: 2022-05-28 00:00:00
# retrieving news from: 2022-05-27 00:00:00
# retrieving news from: 2022-05-26 00:00:00
# retrieving news from: 2022-05-25 00:00:00
# retrieving news from: 2022-05-24 00:00:00
# retrieving news from: 2022-05-23 00:00:00
# retrieving news from: 2022-05-22 00:00:00
# retrieving news from: 2022-05-21 00:00:00
# retrieving news from: 2022-05-20 00:00:00
# retrieving news from: 2022-05-19 00:00:00
# retrieving news from: 2022-05-18 00:00:00
# retrieving news from: 2022-05-17 00:00:00
# retrieving news from: 2022-05-16 00:00:00
# retrieving news from: 2022-05-15 00:00:00
# retrieving news from: 2022-05-14 00:00:00
# retrieving news from: 2022-05-13 00:00:00
# retrieving news from: 2022-05-12 00:00:00
# retrieving news from: 2022-05-11 00:00:00
# retrieving news from: 2022-05-10 00:00:00
# retrieving news from: 2022-05-09 00:00:00
# retrieving news from: 2022-05-08 00:00:00
# retrieving news from: 2022-05-07 00:00:00
# Fetching news about 'trade'
# ******************************
# retrieving news from: 2022-06-05 00:00:00
# retrieving news from: 2022-06-04 00:00:00
# retrieving news from: 2022-06-03 00:00:00
# retrieving news from: 2022-06-02 00:00:00
# retrieving news from: 2022-06-01 00:00:00
# retrieving news from: 2022-05-31 00:00:00
# retrieving news from: 2022-05-30 00:00:00
# retrieving news from: 2022-05-29 00:00:00
# retrieving news from: 2022-05-28 00:00:00
# retrieving news from: 2022-05-27 00:00:00
# retrieving news from: 2022-05-26 00:00:00
# retrieving news from: 2022-05-25 00:00:00
# retrieving news from: 2022-05-24 00:00:00
# retrieving news from: 2022-05-23 00:00:00
# retrieving news from: 2022-05-22 00:00:00
# retrieving news from: 2022-05-21 00:00:00
# retrieving news from: 2022-05-20 00:00:00
# retrieving news from: 2022-05-19 00:00:00
# retrieving news from: 2022-05-18 00:00:00
# retrieving news from: 2022-05-17 00:00:00
# retrieving news from: 2022-05-16 00:00:00
# retrieving news from: 2022-05-15 00:00:00
# retrieving news from: 2022-05-14 00:00:00
# retrieving news from: 2022-05-13 00:00:00
# retrieving news from: 2022-05-12 00:00:00
# retrieving news from: 2022-05-11 00:00:00
# retrieving news from: 2022-05-10 00:00:00
# retrieving news from: 2022-05-09 00:00:00
# retrieving news from: 2022-05-08 00:00:00
# retrieving news from: 2022-05-07 00:00:00
# Fetching news about 'economy'
# ******************************
# retrieving news from: 2022-06-05 00:00:00
# retrieving news from: 2022-06-04 00:00:00
# retrieving news from: 2022-06-03 00:00:00
# retrieving news from: 2022-06-02 00:00:00
# retrieving news from: 2022-06-01 00:00:00
# retrieving news from: 2022-05-31 00:00:00
# retrieving news from: 2022-05-30 00:00:00
# retrieving news from: 2022-05-29 00:00:00
# retrieving news from: 2022-05-28 00:00:00
# retrieving news from: 2022-05-27 00:00:00
# retrieving news from: 2022-05-26 00:00:00
# retrieving news from: 2022-05-25 00:00:00
# retrieving news from: 2022-05-24 00:00:00
# retrieving news from: 2022-05-23 00:00:00
# retrieving news from: 2022-05-22 00:00:00
# retrieving news from: 2022-05-21 00:00:00
# retrieving news from: 2022-05-20 00:00:00
# retrieving news from: 2022-05-19 00:00:00
# retrieving news from: 2022-05-18 00:00:00
# retrieving news from: 2022-05-17 00:00:00
# retrieving news from: 2022-05-16 00:00:00
# retrieving news from: 2022-05-15 00:00:00
# retrieving news from: 2022-05-14 00:00:00
# retrieving news from: 2022-05-13 00:00:00
# retrieving news from: 2022-05-12 00:00:00
# retrieving news from: 2022-05-11 00:00:00
# retrieving news from: 2022-05-10 00:00:00
# retrieving news from: 2022-05-09 00:00:00
# retrieving news from: 2022-05-08 00:00:00
# retrieving news from: 2022-05-07 00:00:00
#                                           aaple_news  \
# 0  [How to Use a Laptop as a Second Display for Y...
# 1  [Apple is reportedly enlisting Hollywood talen...
# 2  [Square will support Apple's Tap to Pay on iPh...
# 3  [How to use your smartwatch as a camera remote...
# 4  [How to Watch Apple's WWDC 2022, The iPhone 14...
#
#                                           trade_news  \
# 0  [Blue Jays trade Ryan Borucki to Mariners for ...
# 1  [Peter Navarro Vowed Revenge On Biden Before B...
# 2  [Factbox: What could the WTO ministerial confe...
# 3  [Chipotle Lovers Can Now Buy Burritos With Bit...
# 4  [Facebook and Instagram’s parent company will ...
#
#                                         economy_news       date
# 0  [US Unemployment drops to lowest level since 1... 2022-06-05
# 1  [Tesla CEO Elon Musk Has 'Super Bad Feeling' A... 2022-06-04
# 2  [Biden brushes off Musk's warnings about the e... 2022-06-03
# 3  [Time is running out for Russia, German econom... 2022-06-02
# 4  [How the UAE went from boycotting Israel to in... 2022-06-01

# %%
# Get second topic
def score(headlines):
    """
        This function takes all headlines for a given day, gets the average sentiment score for all of them
    """
    analyzer = SentimentIntensityAnalyzer()
    scores = [analyzer.polarity_scores(headline)["compound"]for headline in headlines]
    return sum(scores) / len(scores)


new_df["aaple_scored"] = new_df["aaple_news"].apply(score)
new_df["trade_scored"] = new_df["trade_news"].apply(score)
new_df["economy_scored"] = new_df["economy_news"].apply(score)

new_df.head()
# Out:
#                                           aaple_news  \
# 0  [How to Use a Laptop as a Second Display for Y...
# 1  [Apple is reportedly enlisting Hollywood talen...
# 2  [Square will support Apple's Tap to Pay on iPh...
# 3  [How to use your smartwatch as a camera remote...
# 4  [How to Watch Apple's WWDC 2022, The iPhone 14...
#
#                                           trade_news  \
# 0  [Blue Jays trade Ryan Borucki to Mariners for ...
# 1  [Peter Navarro Vowed Revenge On Biden Before B...
# 2  [Factbox: What could the WTO ministerial confe...
# 3  [Chipotle Lovers Can Now Buy Burritos With Bit...
# 4  [Facebook and Instagram’s parent company will ...
#
#                                         economy_news       date  aaple_scored  \
# 0  [US Unemployment drops to lowest level since 1... 2022-06-05      0.033060
# 1  [Tesla CEO Elon Musk Has 'Super Bad Feeling' A... 2022-06-04      0.102585
# 2  [Biden brushes off Musk's warnings about the e... 2022-06-03      0.243345
# 3  [Time is running out for Russia, German econom... 2022-06-02      0.087085
# 4  [How the UAE went from boycotting Israel to in... 2022-06-01     -0.026900
#
#    trade_scored  economy_scored
# 0      0.128430        0.031120
# 1     -0.131365       -0.010195
# 2     -0.126960       -0.088225
# 3      0.034240        0.043555
# 4     -0.088900       -0.055425

# %%
# Get third topic
new_df.index = new_df["date"]
new_df.head()
# Out:
#                                                    aaple_news  \
# date
# 2022-06-05  [How to Use a Laptop as a Second Display for Y...
# 2022-06-04  [Apple is reportedly enlisting Hollywood talen...
# 2022-06-03  [Square will support Apple's Tap to Pay on iPh...
# 2022-06-02  [How to use your smartwatch as a camera remote...
# 2022-06-01  [How to Watch Apple's WWDC 2022, The iPhone 14...
#
#                                                    trade_news  \
# date
# 2022-06-05  [Blue Jays trade Ryan Borucki to Mariners for ...
# 2022-06-04  [Peter Navarro Vowed Revenge On Biden Before B...
# 2022-06-03  [Factbox: What could the WTO ministerial confe...
# 2022-06-02  [Chipotle Lovers Can Now Buy Burritos With Bit...
# 2022-06-01  [Facebook and Instagram’s parent company will ...
#
#                                                  economy_news       date  \
# date
# 2022-06-05  [US Unemployment drops to lowest level since 1... 2022-06-05
# 2022-06-04  [Tesla CEO Elon Musk Has 'Super Bad Feeling' A... 2022-06-04
# 2022-06-03  [Biden brushes off Musk's warnings about the e... 2022-06-03
# 2022-06-02  [Time is running out for Russia, German econom... 2022-06-02
# 2022-06-01  [How the UAE went from boycotting Israel to in... 2022-06-01
#
#             aaple_scored  trade_scored  economy_scored
# date
# 2022-06-05      0.033060      0.128430        0.031120
# 2022-06-04      0.102585     -0.131365       -0.010195
# 2022-06-03      0.243345     -0.126960       -0.088225
# 2022-06-02      0.087085      0.034240        0.043555
# 2022-06-01     -0.026900     -0.088900       -0.055425

# %%
# Instantiate SentimentIntensityAnalyzer
# YOUR CODE HERE

# %%
# Create function that computes average compound sentiment of headlines for each day
def headline_sentiment_summarizer_avg(headlines):
    sentiment = []
    for day in headlines:
        day_score = []
        for h in day:
            if h == None:
                continue
            else:
                day_score.append(sid.polarity_scores(h)["compound"])
        sentiment.append(sum(day_score) / len(day_score))
    return sentiment

# %%
# Merge with AAPL returns
df.index = pd.to_datetime(df.index)

all_df = pd.concat([df, new_df], join="inner", axis="columns")

# Display data
all_df = all_df[["close","aaple_scored", "trade_scored", "economy_scored"]]

all_df.head()
# Out:
#              close  aaple_scored  trade_scored  economy_scored
# 2022-05-09  152.06      0.052440     -0.026415       -0.020650
# 2022-05-10  154.51      0.111660      0.024040       -0.188515
# 2022-05-11  146.50      0.042070     -0.027030       -0.122380
# 2022-05-12  142.56      0.079985      0.018275        0.036440
# 2022-05-13  147.11      0.023630      0.112405       -0.040805

# %%
# Correlate the headlines' sentiment to returns
all_df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_39f0e_row0_col0, #T_39f0e_row1_col1, #T_39f0e_row2_col2, #T_39f0e_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_39f0e_row0_col1, #T_39f0e_row0_col3, #T_39f0e_row1_col0, #T_39f0e_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_39f0e_row0_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_39f0e_row1_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_39f0e_row2_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_39f0e_row2_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_39f0e_row2_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_39f0e_row3_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_39f0e_row3_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_39f0e_row3_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# </style>
# <table id="T_39f0e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >close</th>
#       <th class="col_heading level0 col1" >aaple_scored</th>
#       <th class="col_heading level0 col2" >trade_scored</th>
#       <th class="col_heading level0 col3" >economy_scored</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39f0e_level0_row0" class="row_heading level0 row0" >close</th>
#       <td id="T_39f0e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_39f0e_row0_col1" class="data row0 col1" >-0.164685</td>
#       <td id="T_39f0e_row0_col2" class="data row0 col2" >0.084630</td>
#       <td id="T_39f0e_row0_col3" class="data row0 col3" >-0.082950</td>
#     </tr>
#     <tr>
#       <th id="T_39f0e_level0_row1" class="row_heading level0 row1" >aaple_scored</th>
#       <td id="T_39f0e_row1_col0" class="data row1 col0" >-0.164685</td>
#       <td id="T_39f0e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_39f0e_row1_col2" class="data row1 col2" >-0.075222</td>
#       <td id="T_39f0e_row1_col3" class="data row1 col3" >0.098846</td>
#     </tr>
#     <tr>
#       <th id="T_39f0e_level0_row2" class="row_heading level0 row2" >trade_scored</th>
#       <td id="T_39f0e_row2_col0" class="data row2 col0" >0.084630</td>
#       <td id="T_39f0e_row2_col1" class="data row2 col1" >-0.075222</td>
#       <td id="T_39f0e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_39f0e_row2_col3" class="data row2 col3" >0.115267</td>
#     </tr>
#     <tr>
#       <th id="T_39f0e_level0_row3" class="row_heading level0 row3" >economy_scored</th>
#       <td id="T_39f0e_row3_col0" class="data row3 col0" >-0.082950</td>
#       <td id="T_39f0e_row3_col1" class="data row3 col1" >0.098846</td>
#       <td id="T_39f0e_row3_col2" class="data row3 col2" >0.115267</td>
#       <td id="T_39f0e_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
