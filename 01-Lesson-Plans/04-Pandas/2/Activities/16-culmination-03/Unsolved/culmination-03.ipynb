# %% [markdown]
# # World Happiness

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# Import dependencies
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## 2. Set File Path to CSV using Pathlib

# %%
# Create reference to CSV file
# Hint - the file path may require some extra steps..
pathfile="../Resources/world_happiness.csv"

# %% [markdown]
# ## 3. Import CSV into Pandas DataFrame

# %%
# Import the CSV into a pandas DataFrame
happiness_df=pd.read_csv(pathfile, low_memory=False)
happiness_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %% [markdown]
# ## 4. Set Index and Sort Index in Ascending Order

# %%
# Set new index to Country
happiness_df = happiness_df.set_index("Country")

# Sort the new dataframe alphabetically
happiness_df.sort_index(inplace=True)
happiness_df.head(40)
# Out:
#                           Happiness.Rank  Happiness.Score  Whisker.high  \
# Country
# Afghanistan                          141            3.794      3.873661
# Albania                              109            4.644      4.752464
# Algeria                               53            5.872      5.978286
# Angola                               140            3.795      3.951642
# Argentina                             24            6.599      6.690085
# Armenia                              121            4.376      4.466735
# Australia                             10            7.284      7.356651
# Austria                               13            7.006      7.070670
# Azerbaijan                            85            5.234      5.299287
# Bahrain                               41            6.087      6.178989
# Bangladesh                           110            4.608      4.689822
# Belarus                               67            5.569      5.646114
# ...

# %% [markdown]
# ## 5. Select the Happiness Score for Vietnam

# %%
# Grab the data contained within the row of a country of your choice and the "Happiness.Score" column
# Print the result as "<country's name> happiness score for 2017 was <happiness score>"
alb_happiness = happiness_df.loc["Albania", "Happiness.Score"]
print("Albania's happiness score for 2017 was: " + str(alb_happiness))
# Out:
# Albania's happiness score for 2017 was: 4.64400005340576

# %% [markdown]
# ## 6. Select the Happiness Rank and Score for Belgium, Belize, Benin, Bhutan, and Bolivia

# %%
# Grab all rows of data from "Belgium" to "Bolivia" and the columns from "Happiness.Rank" to "Happiness.Score"
# Hint - in order to view more data you will need to increase the dataframe's head
belgium_to_bolivia = happiness_df.loc[["Belgium", "Belize", "Benin","Bhutan", "Bolivia"], ["Happiness.Rank", "Happiness.Score"]]
belgium_to_bolivia
# Out:
#          Happiness.Rank  Happiness.Score
# Country
# Belgium              17            6.891
# Belize               50            5.956
# Benin               143            3.657
# Bhutan               97            5.011
# Bolivia              58            5.823

# %% [markdown]
# ## 7. Select the Freedom and Government Trust for Every Country

# %%
# Select all rows and only display the columns for "Freedom" and "Trust..Government.Corruption." 
happiness_df.loc[:,["Freedom","Trust..Government.Corruption."]].head(100)
# Out:
#               Freedom  Trust..Government.Corruption.
# Country
# Afghanistan  0.106180                       0.061158
# Albania      0.381499                       0.039864
# Algeria      0.233336                       0.146096
# Angola       0.000000                       0.069720
# Argentina    0.494519                       0.059740
# ...               ...                            ...
# Myanmar      0.514492                       0.188816
# Namibia      0.520304                       0.093147
# Nepal        0.440306                       0.072976
# Netherlands  0.585384                       0.282662
# New Zealand  0.614062                       0.382817
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 8. Select all the Countries Where GDP is Greater than or Equal to 1.6

# %%
# Select all rows where the GDP per capita has a value greater than or equal to 1.6
gdp_score = happiness_df.loc[happiness_df["Economy..GDP.per.Capita."]>=1.6, :]
gdp_score.head()
# Out:
#             Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# Country
# Kuwait                  39            6.105      6.191957     6.018043
# Luxembourg              18            6.863      6.923686     6.802314
# Norway                   1            7.537      7.594445     7.479556
# Qatar                   35            6.375      6.568477     6.181523
# Singapore               26            6.572      6.636723     6.507277
#
#             Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# Country
# Kuwait                      1.632952  1.259699                  0.632106
# Luxembourg                  1.741944  1.457584                  0.845089
# Norway                      1.616463  1.533524                  0.796667
# Qatar                       1.870766  1.274297                  0.710098
# Singapore                   1.692278  1.353814                  0.949492
#
#              Freedom  Generosity  Trust..Government.Corruption.  \
# Country
# ...

# %% [markdown]
# ## 9. Select all the Countries Where the Happiness Score is Greater than or Equal to 5 and GDP is Less than or Equal to 1

# %%
# Select all rows that have a happiness score greater than or equal 5 and a GDP score less than or equal 1
poor_happiness = happiness_df.loc[(happiness_df["Happiness.Score"]>=5) & (happiness_df["Economy..GDP.per.Capita."]<=1), :]
poor_happiness.head(100)
# Out:
#                         Happiness.Rank  Happiness.Score  Whisker.high  \
# Country
# Belize                              50            5.956      6.197242
# Bhutan                              97            5.011      5.079335
# Bolivia                             58            5.823      5.903977
# Bosnia and Herzegovina              90            5.182      5.276336
# El Salvador                         45            6.003      6.108635
# Guatemala                           29            6.454      6.566874
# Honduras                            91            5.181      5.301583
# Indonesia                           81            5.262      5.352889
# Jamaica                             76            5.311      5.581399
# Jordan                              74            5.336      5.448410
# Kosovo                              78            5.279      5.364848
# Kyrgyzstan                          98            5.004      5.089920
# ...

# %%
poor_happiness.plot(figsize=(22,11), kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>
